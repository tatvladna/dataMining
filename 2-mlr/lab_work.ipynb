# %%
import os
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.image as mpimg
import dill
import pandas as pd


def display_images(folder_path):
    for filename in os.listdir(folder_path):
        img_path = os.path.join(folder_path, filename)
        img = mpimg.imread(img_path)
        plt.figure(figsize=(8, 8)) 
        plt.imshow(img)
        plt.axis('off')
        plt.title(filename)
        plt.show()

# %% [markdown]
# -------------
#
# # Результаты Ridge

# %%
plot_folder= 'plot' 
display_images(plot_folder)

# %% [markdown]
# ----------
#
# # Pipeline

# %%
# Загрузим рандомный трансформер

with open("models/RidgeMinMaxSc_33%.pkl", 'rb') as file:
    transformer_ridge = dill.load(file)

display(transformer_ridge)
# Out:
# Pipeline(steps=[('scaler',
#                  Pipeline(steps=[('get_scaled_descriptors',
#                                   FunctionTransformer(func=<function get_base_features.<locals>.<lambda> at 0x7fde9caab4c0>))])),
#                 ('model',
#                  Ridge(alpha=np.float64(0.11), max_iter=10000, solver='svd'))])

# %% [markdown]
# -------------
#
# # Результаты

# %%
results = pd.read_csv("ridge.csv")
results
# Out:
#                                      model size_x_test  r2_train  q2_test  \
# 0        RidgeMinMaxSc_0.3333333333333333%         33%      0.65     0.65
# 1                      RidgeMinMaxSc_0.25%         25%      0.66     0.64
# 2                       RidgeMinMaxSc_0.2%         20%      0.66     0.67
# 3                       RidgeMinMaxSc_0.1%         10%      0.66     0.67
# 4           RidgeStdSc_0.3333333333333333%         33%      0.65     0.66
# 5                         RidgeStdSc_0.25%         25%      0.66     0.64
# 6                          RidgeStdSc_0.2%         20%      0.66     0.67
# 7                          RidgeStdSc_0.1%         10%      0.66     0.67
# 8      RidgeLassoStdSc_0.3333333333333333%         33%      0.83     0.67
# 9                    RidgeLassoStdSc_0.25%         25%      0.83     0.62
# 10                    RidgeLassoStdSc_0.2%         20%      0.82     0.64
# 11                    RidgeLassoStdSc_0.1%         10%      0.81     0.67
# 12  RidgeLassoMinMaxSc_0.3333333333333333%         33%      0.82     0.69
# 13                RidgeLassoMinMaxSc_0.25%         25%      0.82     0.64
# 14                 RidgeLassoMinMaxSc_0.2%         20%      0.82     0.67
# 15                 RidgeLassoMinMaxSc_0.1%         10%      0.80     0.69
# 16       RidgePCAStdSc_0.3333333333333333%         33%      0.04     0.01
# 17                     RidgePCAStdSc_0.25%         25%      0.03     0.01
# 18                      RidgePCAStdSc_0.2%         20%      0.03     0.02
# 19                      RidgePCAStdSc_0.1%         10%      0.03     0.01
# 20    RidgePCAMinMaxSc_0.3333333333333333%         33%      0.13     0.13
# 21                  RidgePCAMinMaxSc_0.25%         25%      0.13     0.11
# 22                   RidgePCAMinMaxSc_0.2%         20%      0.13     0.12
# 23                   RidgePCAMinMaxSc_0.1%         10%      0.13     0.10
#
#     rmse  mean_time_fit_s_cv  mean_ram_fit_mb  size_model_pipeline_mb  grade  \
# 0   0.80                0.00             0.00                    0.00  False
# 1   0.79                0.01             0.00                    0.00  False
# 2   0.77                0.00             0.00                    0.00  False
# 3   0.83                0.00             0.00                    0.00  False
# 4   0.80                0.00             0.00                    0.00  False
# 5   0.79                0.00             0.00                    0.00  False
# 6   0.77                0.00             0.00                    0.00  False
# 7   0.83                0.00             0.00                    0.00  False
# 8   0.71                0.01             0.10                    0.01  False
# 9   0.77                0.01             0.00                    0.01  False
# 10  0.77                0.86             0.00                    0.01  False
# 11  0.69                0.94             0.04                    0.01  False
# 12  0.70                0.07             0.00                    0.01  False
# 13  0.75                0.01             0.06                    0.01  False
# 14  0.74                0.01             0.00                    0.01  False
# 15  0.67                0.26             0.00                    0.01  False
# 16  1.24                0.00             0.00                    0.00  False
# 17  1.24                0.00             0.00                    0.00  False
# 18  1.27                0.00             0.00                    0.00  False
# 19  1.19                0.01             0.00                    0.00  False
# 20  1.16                0.00             0.00                    0.00  False
# 21  1.18                0.00             0.00                    0.00  False
# 22  1.21                0.00             0.00                    0.00  False
# 23  1.14                0.00             0.00                    0.00  False
#
#                                                params
# 0        {'alpha': np.float64(0.11), 'solver': 'svd'}
# 1   {'alpha': np.float64(0.06999999999999999), 'so...
# 2       {'alpha': np.float64(0.05), 'solver': 'lsqr'}
# 3       {'alpha': np.float64(0.01), 'solver': 'auto'}
# 4       {'alpha': np.float64(4.58), 'solver': 'auto'}
# 5       {'alpha': np.float64(5.13), 'solver': 'lsqr'}
# 6       {'alpha': np.float64(1.12), 'solver': 'lsqr'}
# 7        {'alpha': np.float64(0.26), 'solver': 'svd'}
# 8                  {'alpha': 0.011, 'solver': 'lsqr'}
# 9                  {'alpha': 0.011, 'solver': 'lsqr'}
# 10                 {'alpha': 0.011, 'solver': 'saga'}
# 11                 {'alpha': 0.011, 'solver': 'saga'}
# 12                  {'alpha': 0.001, 'solver': 'svd'}
# 13                 {'alpha': 0.001, 'solver': 'auto'}
# 14                 {'alpha': 0.001, 'solver': 'lsqr'}
# 15                 {'alpha': 0.001, 'solver': 'saga'}
# 16     {'alpha': np.float64(14.32), 'solver': 'lsqr'}
# 17  {'alpha': np.float64(19.990000000000002), 'sol...
# 18     {'alpha': np.float64(16.76), 'solver': 'lsqr'}
# 19     {'alpha': np.float64(19.92), 'solver': 'saga'}
# 20      {'alpha': np.float64(1.29), 'solver': 'saga'}
# 21      {'alpha': np.float64(2.11), 'solver': 'saga'}
# 22       {'alpha': np.float64(1.8), 'solver': 'saga'}
# 23      {'alpha': np.float64(1.82), 'solver': 'saga'}
